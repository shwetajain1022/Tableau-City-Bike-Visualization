# %%
# Import the dependencies
import pandas as pd

# %%
# Set the column width
pd.options.display.max_colwidth = 200
# Read in the dataset. 
cb_202211_df = pd.read_csv("Summer Months/summermonths_data.csv")
cb_202211_df["season"] = "summer"
cb_202211_df.head()
# Out:
# c:\Users\shweta.jain\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0           ride_id  rideable_type           started_at  \
# 0           0  2E89F1D88B8347E6   classic_bike  2022-04-08 19:50:00
# 1           1  43F6D61DFEDAE4AF  electric_bike  2022-04-27 10:19:54
# 2           2  21C7076071104314   classic_bike  2022-04-28 13:10:59
# 3           3  7D7CEA2953427D0C   classic_bike  2022-04-13 20:21:18
# 4           4  AD7E176748A4A55E  electric_bike  2022-04-29 18:56:24
#
#               ended_at        start_station_name start_station_id  \
# 0  2022-04-08 19:55:28           E 89 St & 3 Ave          7265.10
# 1  2022-04-27 10:33:29        Broadway & W 29 St          6289.06
# 2  2022-04-28 13:17:18  E 123 St & Lexington Ave          7636.05
# ...

# %%
cb_202212_df = pd.read_csv("Winter Months/wintermonths_data.csv")
cb_202212_df["season"] = "winter"
cb_202212_df.head()
# Out:
# c:\Users\shweta.jain\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0           ride_id rideable_type           started_at  \
# 0           0  211A73DFC6752EFC  classic_bike  2022-11-30 21:36:23
# 1           1  568E7F54B3EFB8C3  classic_bike  2022-11-20 11:06:30
# 2           2  0ED37DE3609F47A1  classic_bike  2022-11-17 09:48:34
# 3           3  AF0F9BAB2B4AA126  classic_bike  2022-11-02 12:23:36
# 4           4  215FF85772BA2D2B  classic_bike  2022-11-07 16:46:20
#
#               ended_at          start_station_name start_station_id  \
# 0  2022-11-30 21:49:31             2 Ave & E 29 St          6122.09
# 1  2022-11-20 11:17:18       E 97 St & Madison Ave          7393.09
# 2  2022-11-17 09:56:14       E 97 St & Madison Ave          7393.09
# ...

# %%
cb_202211_df_1 =cb_202211_df.drop(['Unnamed: 0'],axis=1)
cb_202212_df_2 = cb_202212_df.drop(['Unnamed: 0'],axis=1)

# %%
cb_202211_df_1.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  2E89F1D88B8347E6   classic_bike  2022-04-08 19:50:00  2022-04-08 19:55:28
# 1  43F6D61DFEDAE4AF  electric_bike  2022-04-27 10:19:54  2022-04-27 10:33:29
# 2  21C7076071104314   classic_bike  2022-04-28 13:10:59  2022-04-28 13:17:18
# 3  7D7CEA2953427D0C   classic_bike  2022-04-13 20:21:18  2022-04-13 20:37:28
# 4  AD7E176748A4A55E  electric_bike  2022-04-29 18:56:24  2022-04-29 18:57:16
#
#          start_station_name start_station_id          end_station_name  \
# 0           E 89 St & 3 Ave          7265.10     Madison Ave & E 99 St
# 1        Broadway & W 29 St          6289.06        Broadway & W 29 St
# 2  E 123 St & Lexington Ave          7636.05  E 123 St & Lexington Ave
# 3           W 36 St & 9 Ave          6569.07           W 36 St & 9 Ave
# 4   Graham Ave & Withers St          5403.04   Graham Ave & Withers St
#
# ...

# %%
# cb_202301_df = pd.read_csv("202206/202206-citbike-tripdata.csv")
# cb_202301_df.head()

# %%
cb_202211_202212_df =  pd.concat([cb_202211_df_1,cb_202212_df_2],ignore_index=True,axis=0)
cb_202211_202212_df.count()
# Out:
# ride_id               14658054
# rideable_type         14658054
# started_at            14658054
# ended_at              14658054
# start_station_name    14657964
# start_station_id      14657964
# end_station_name      14628970
# end_station_id        14628970
# start_lat             14658054
# start_lng             14658054
# end_lat               14644149
# end_lng               14644149
# member_casual         14658054
# season                14658054
# dtype: int64

# %%
cb_202211_202212_df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'season'],
#       dtype='object')

# %%
#cb_202211_202212_df_1 = cb_202211_202212_df.drop(['Unnamed: 0'],axis=1)

# %%
cb_202211_202212_df.to_csv('my_data.csv',index=False)

# %%
# with open('citybike_data.csv', 'w') as csv_file:
    # cb_202211_202212_df.to_csv(path_or_buf=csv_file,index=False)

# %%
citybike_data_df = pd.read_csv("citybike_data.csv")
# citybike_data_df.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1)
citybike_data_df.head(20)
# Out:
# c:\Users\shweta.jain\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              ride_id  rideable_type           started_at             ended_at  \
# 0   2E89F1D88B8347E6   classic_bike  2022-04-08 19:50:00  2022-04-08 19:55:28
# 1   43F6D61DFEDAE4AF  electric_bike  2022-04-27 10:19:54  2022-04-27 10:33:29
# 2   21C7076071104314   classic_bike  2022-04-28 13:10:59  2022-04-28 13:17:18
# 3   7D7CEA2953427D0C   classic_bike  2022-04-13 20:21:18  2022-04-13 20:37:28
# 4   AD7E176748A4A55E  electric_bike  2022-04-29 18:56:24  2022-04-29 18:57:16
# 5   26911119A3403809  electric_bike  2022-04-01 18:02:34  2022-04-01 18:05:37
# 6   A24ED982F8EC8A71   classic_bike  2022-04-18 14:50:45  2022-04-18 15:32:32
# 7   B26F0EAE36F2BFE4   classic_bike  2022-04-15 06:21:48  2022-04-15 06:44:36
# ...

# %%
citybike_data_df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'season'],
#       dtype='object')

# %%
df2=citybike_data_df.loc[(citybike_data_df['start_station_name'] == 'Broadway & E 14 St')]

# %%
df2["start_station_id"] = df2["start_station_id"].to_string()
df2["start_station_id"].unique()
# Out:
# c:\Users\shweta.jain\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ...

# %%
df2.head(50)
# Out:
#                 ride_id  rideable_type           started_at  \
# 8986   FAED1DD9165222A6   classic_bike  2022-04-10 17:11:31
# 10289  982E8BF5C47E76CB   classic_bike  2022-04-03 19:02:42
# 11731  78AD960BCAB0AD65  electric_bike  2022-04-14 16:07:38
# 11733  D617BC76B0572BFC   classic_bike  2022-04-01 14:19:18
# 11734  05E7C18CFB5EE278   classic_bike  2022-04-14 12:29:57
# 12677  4DA2A482C11FCA2C    docked_bike  2022-04-26 18:01:44
# 14971  80877DC6CFBC0902   classic_bike  2022-04-27 14:50:57
# 17339  523D459BF766203E   classic_bike  2022-04-27 20:05:43
# 17464  DFE06BEFCCCDBF5F   classic_bike  2022-04-19 14:26:33
# 19314  06DB79FBD87FD7F0   classic_bike  2022-04-26 16:38:56
# 19315  E0C5220F6CD212B4   classic_bike  2022-04-13 12:43:01
# 21387  619C67D4F82D94B0   classic_bike  2022-04-28 23:18:29
# 21618  D52E4E074746B3F1   classic_bike  2022-04-11 10:21:01
# 21619  2B6AB930446151EB   classic_bike  2022-04-01 17:39:53
# 22831  B196F47D1E9BC9D4   classic_bike  2022-04-08 16:36:01
# ...

# %%
df2["start_lat"].unique()
# Out:
# array([40.73454567, 40.734546  , 40.73415879, ..., 40.73425257,
#        40.73471987, 40.73410141])

# %%
df2["start_lat"] = df2["start_lat"].round()
df2["start_lat"].unique()
# Out:
# c:\Users\shweta.jain\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# array([41.])

# %%
df2["start_lng"].unique()
# Out:
# array([-73.99074142, -73.990741  , -73.99088823, ..., -73.99067879,
#        -73.99055743, -73.99074841])

# %%
df2["start_station_id"].unique()
# Out:
# array(['5905.12', 5905.12], dtype=object)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47478 entries, 8986 to 14656967
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             47478 non-null  object
#  1   rideable_type       47478 non-null  object
#  2   started_at          47478 non-null  object
#  3   ended_at            47478 non-null  object
#  4   start_station_name  47478 non-null  object
#  5   start_station_id    47478 non-null  object
#  6   end_station_name    47401 non-null  object
#  7   end_station_id      47401 non-null  object
#  8   start_lat           47478 non-null  float64
#  9   start_lng           47478 non-null  float64
#  10  end_lat             47431 non-null  float64
#  11  end_lng             47431 non-null  float64
#  12  member_casual       47478 non-null  object
#  13  season              47478 non-null  object
# dtypes: float64(4), object(10)
# memory usage: 5.4+ MB
